# %% [markdown]
# # Face Detection with OpenCv

# %% [markdown]
# **Import library's**

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# **Load the image**

# %%
nadia = cv2.imread("/Users/neemiasbsilva/Downloads/Computer-Vision-with-Python/DATA/Nadia_Murad.jpg", 0)
denis = cv2.imread("/Users/neemiasbsilva/Downloads/Computer-Vision-with-Python/DATA/Denis_Mukwege.jpg", 0)
solvay = cv2.imread("/Users/neemiasbsilva/Downloads/Computer-Vision-with-Python/DATA/solvay_conference.jpg", 0)

# %%
# show the nadia image
plt.imshow(nadia, cmap='gray')

# %%
# show the denis image
plt.imshow(denis, cmap='gray')

# %%
plt.imshow(solvay, cmap='gray')

# %% [markdown]
# **Load the Frontal Cascade Classifier**

# %%
face_cascade = cv2.CascadeClassifier('/Users/neemiasbsilva/Downloads/Computer-Vision-with-Python/DATA/haarcascades/haarcascade_frontalface_default.xml')

# %%
def detect_face(img):
    
    face_img = img.copy()
    
    face_rectangles = face_cascade.detectMultiScale(face_img)
    
    for (x, y, w, h) in face_rectangles:
        cv2.rectangle(face_img, (x, y), (x+w, y+h), (255, 0, 255), 10)
        
    return face_img

# %%
result_denis = detect_face(denis)

# %%
plt.imshow(result_denis, cmap='gray')

# %%
result_nadia = detect_face(nadia)
plt.imshow(result_nadia, cmap='gray')

# %%
result_solvay = detect_face(solvay)
plt.imshow(result_solvay, cmap='gray')

# %% [markdown]
# **Adjusting the Detect Face**

# %%
def adj_detect_face(img):
    
    face_img = img.copy()
    
    face_rectangles = face_cascade.detectMultiScale(face_img, scaleFactor=1.2, minNeighbors=5)
    
    for (x, y, w, h) in face_rectangles:
        cv2.rectangle(face_img, (x, y), (x+w, y+h), (255, 0, 255), 10)
        
    return face_img

# %%
result_solvay = adj_detect_face(solvay)
plt.imshow(result_solvay, cmap='gray')

# %% [markdown]
# **Detect Eyes Cascade Classifier**

# %%
eye_cascade = cv2.CascadeClassifier("/Users/neemiasbsilva/Downloads/Computer-Vision-with-Python/DATA/haarcascades/haarcascade_eye.xml")

# %%
def detect_eyes(img):
    
    face_img = img.copy()
    
    eyes_rectangles = eye_cascade.detectMultiScale(face_img, scaleFactor=1.2, minNeighbors=5)
    
    for (x, y, w, h) in eyes_rectangles:
        
        cv2.rectangle(face_img, (x, y), (x+w, y+h), (255, 255, 255), 10)
        
    return face_img

# %%
result_nadia_eyes = detect_eyes(nadia)
plt.imshow(result_nadia_eyes, cmap='gray')

# %%
# doesn't work because the region of eyes is the same of the region
# of interest, for more details check the Viola Algorithms
result_denis_eyes = detect_eyes(denis)
plt.imshow(result_denis_eyes, cmap='gray')
