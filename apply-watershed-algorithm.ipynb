# %% [markdown]
# # Apply Watershed Algorithm to Coin Next to Table Image
#
# ### For more details, please: <a href="https://en.wikipedia.org/wiki/Watershed_(image_processing)">Click Here</a>.

# %% [markdown]
# **Import library's**

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# **Create display function**

# %%
def display(img, cmap='gray'):
    fig = plt.figure(figsize=(12, 10))
    ax = fig.add_subplot(111)
    ax.imshow(img, cmap)

# %% [markdown]
# **Load the image**

# %%
sep_coins = cv2.imread("/Users/neemiasbsilva/Downloads/Computer-Vision-with-Python/DATA/pennies.jpg")

# %%
display(sep_coins)
